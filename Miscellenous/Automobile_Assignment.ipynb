# %% [markdown]
# # Final Assignment: Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

df = pd.read_csv("/Users/itsarifworld/Desktop/automobile_dataset.csv")
df.head()
# Out:
#    Year  Month Vehicle_Type  Recession  Automobile_Sales  \
# 0  2000      1        Sedan          0              1632
# 1  2000      1          SUV          0              1159
# 2  2000      1        Truck          0              4102
# 3  2000      1    Hatchback          0              3519
# 4  2000      2        Sedan          0              5540
#
#    Advertising_Expenditure  Avg_Vehicle_Price  Unemployment_Rate   GDP
# 0                      481              49802               8.68  3.59
# 1                      408              24426               6.76  2.67
# 2                      991              28322               4.12  4.89
# 3                      378              25051               5.10  2.56
# 4                      457              49419               4.14  3.34

# %% [markdown]
# ## 1.1 Line Chart

# %%
yearly_sales = df.groupby('Year')['Automobile_Sales'].sum()
plt.figure()
plt.plot(yearly_sales.index, yearly_sales.values, marker='o')
plt.show()

# %% [markdown]
# ## 1.2 Advertising vs Sales

# %%
non_recession = df[df['Recession'] == 0]
plt.figure()
plt.plot(non_recession['Year'], non_recession['Advertising_Expenditure'])
plt.plot(non_recession['Year'], non_recession['Automobile_Sales'])
plt.show()

# %% [markdown]
# ## 1.3 Bar Chart

# %%
recession = df[df['Recession'] == 1]
rec_data = recession.groupby('Vehicle_Type')['Automobile_Sales'].sum()
rec_data.plot(kind='bar')
plt.show()
